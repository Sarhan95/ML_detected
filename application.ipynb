# %%
########### importattion des packages necessaire
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from scipy.stats import mannwhitneyu,ttest_ind

# %%
######### importation des donnes
data=pd.read_csv("creditcard.csv")
data.head()
print("dimension:",data.shape)
# Out:
# dimension: (284807, 31)

# %%
########### inspection des données

data_manquantes=pd.DataFrame({
    'value_nombre':data.isnull().sum(),
    "proportion_manquantes":data.isna().sum()/data.shape[0]

}
    

)
data_manquantes.sort_values("proportion_manquantes",ascending=True)
data_manquantes
# Out:
#         value_nombre  proportion_manquantes
# Time               0                    0.0
# V1                 0                    0.0
# V2                 0                    0.0
# V3                 0                    0.0
# V4                 0                    0.0
# V5                 0                    0.0
# V6                 0                    0.0
# V7                 0                    0.0
# V8                 0                    0.0
# V9                 0                    0.0
# V10                0                    0.0
# V11                0                    0.0
# V12                0                    0.0
# V13                0                    0.0
# V14                0                    0.0
# V15                0                    0.0
# V16                0                    0.0
# V17                0                    0.0
# V18                0                    0.0
# V19                0                    0.0
# ...

# %%
######### analyse univariée
###### variable quantitative*
for col in data.select_dtypes("float"):
    plt.figure()
    sns.displot(data[col])
    plt.show()
    plt.close()
# Out:
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\hp\OneDrive\anaconda\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
############# puisque la majarité des variables suivent une distrubution normale on utilse un teste student
data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
var_quant=data.select_dtypes(exclude="object")

sns.barplot(data=data,x=data["Class"],y=data["V26"])
# Out:
# <Axes: xlabel='Class', ylabel='V26'>

# %%
for var in var_quant:
    plt.figure()
    sns.barplot(x=data[var],y=data["Class"])
    plt.show()

# %%
varss=["Time","V2","Amount","V5"]
fig,axes=plt.subplots(figsize=(8,6))
#axes=axes.flatten()
for i ,var in enumerate(varss):
    sns.histplot(x=data[var],bins=10,kde=True,hue=data["Class"],palette = ["red", "#9FBE16"])
    
    plt.tight_layout()
    plt.show()

# %%
res=pd.DataFrame(columns=["var","statistic_test","p_value"])

for var in varss:
    class_fraud=data.loc[data["Class"]==1,var]
    class_nonfraud=data.loc[data["Class"]==0,var]
    stat,p_values=mannwhitneyu(class_fraud,class_nonfraud,alternative="two-sided")

    res.loc[len(res)]=[var,stat,p_values]
    
    
   
res
# Out:
#       var  statistic_test        p_value
# 0    Time      58572378.0   4.386159e-10
# 1      V2     119593684.0  1.650438e-163
# 2  Amount      61833399.0   8.578472e-06
# 3      V5      40626254.0   3.053712e-58

# %%
######## apprentissage automatique déploiment des modéles
######## divisition notre dataset
x=data.drop("Class",axis=1)
y=data["Class"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=123)
print("dim de x_train:",x_train.shape)
print("dim de x_test:",x_test.shape)
print("dim de y_test:",y_test.shape)
print("dim de y_train:",y_train.shape)
# Out:
# dim de x_train: (170884, 30)
# dim de x_test: (113923, 30)
# dim de y_test: (113923,)
# dim de y_train: (170884,)

# %%
from sklearn.metrics import confusion_matrix,classification_report,f1_score
from sklearn.model_selection import learning_curve


########  regression logistique
rl=LogisticRegression(random_state=123,max_iter=1000)
###### creation une fonction #########
def evaluation(rl):
    rl.fit(x_train,y_train)
    y_pred=rl.predict(x_test)
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    N,train_scores,val_scores=learning_curve(rl,x_train,y_train,cv=5,scoring="f1",train_sizes=np.linspace(0.1,1,10))
    plt.figure(figsize=(10,20))
    plt.plot(N,train_scores.mean(axis=1),label="train_score")
    plt.plot(N,val_scores.mean(axis=1),label="val_score")
    plt.show()

# %%
evaluation(rl)
# Out:
# [[113690     26]
#  [    70    137]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113716
#            1       0.84      0.66      0.74       207
#
#     accuracy                           1.00    113923
#    macro avg       0.92      0.83      0.87    113923
# weighted avg       1.00      1.00      1.00    113923
